# %% [markdown]
# ### Imports & Setup

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
import glob
from ultralytics import YOLO
from collections import defaultdict

# Paths and models
frame_folder = "video_frames"  
output_folder = "angle_overlay_frames"
classification_model = YOLO("runs/detect/train11/weights/best.pt")
pose_model = YOLO("yolo11s-pose.pt")

print("Models loaded successfully!")
# Out:
# Models loaded successfully!

# %% [markdown]
# ### Define path to video. If you want to use a different video, change the path. I provided two videos for convenience

# %%
video_path = "video15.mp4"

# %% [markdown]
# ### Define function to extract frames from video if not already extracted

# %%
def extract_if_needed(video_path, frame_folder, frame_rate=5):
    existing_frames = sorted(glob.glob(os.path.join(frame_folder, "frame_*.jpg")))

    # Quick check: if we already have the correct number of frames, skip
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    expected_frames = math.ceil(total_frames / frame_rate)

    if len(existing_frames) == expected_frames:
        print("Frames already extracted. Skipping.")
        cap.release()
        return

    print("Mismatch detected or missing frames. Re-extracting...")

    # Delete existing frames
    for f in existing_frames:
        os.remove(f)

    # Re-extract
    frame_id = 0
    saved_id = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if frame_id % frame_rate == 0:
            cv2.imwrite(f"{frame_folder}/frame_{saved_id}.jpg", frame)
            saved_id += 1
        frame_id += 1
    cap.release()

# %% [markdown]
# ### Extract frames from video if doesn't exist in video_frames folder

# %%
extract_if_needed(video_path, frame_folder)
# Out:
# Mismatch detected or missing frames. Re-extracting...

# %% [markdown]
# ### Run Classification on Frames and determine max confidence

# %%
# Classify frames and gather confidence scores
class_confidence = defaultdict(list)

for img in os.listdir(frame_folder):
    img_path = os.path.join(frame_folder, img)
    results = classification_model(img_path)
    for r in results:
        if r.boxes is not None and len(r.boxes.cls) > 0:
            for cls_id, conf in zip(r.boxes.cls, r.boxes.conf):
                class_name = classification_model.names[int(cls_id)]
                class_confidence[class_name].append(float(conf))

# Determine max confidence per class
max_confidence = {cls: max(confs) for cls, confs in class_confidence.items() if confs}
# Out:
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_0.jpg: 384x640 1 deadlift, 1 hip thrust, 1 push up, 359.6ms
# Speed: 4.5ms preprocess, 359.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_1.jpg: 384x640 1 deadlift, 1 hip thrust, 1 push up, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_10.jpg: 384x640 1 push up, 13.7ms
# Speed: 2.4ms preprocess, 13.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_100.jpg: 384x640 1 push up, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_101.jpg: 384x640 1 push up, 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_102.jpg: 384x640 1 push up, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_103.jpg: 384x640 2 push ups, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_104.jpg: 384x640 1 push up, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_105.jpg: 384x640 1 push up, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_106.jpg: 384x640 1 push up, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_107.jpg: 384x640 1 push up, 13.3ms
# Speed: 2.3ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_108.jpg: 384x640 1 push up, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_109.jpg: 384x640 1 push up, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_11.jpg: 384x640 1 hip thrust, 1 push up, 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_110.jpg: 384x640 1 push up, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_111.jpg: 384x640 1 push up, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_112.jpg: 384x640 1 push up, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_113.jpg: 384x640 1 push up, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_114.jpg: 384x640 1 push up, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_115.jpg: 384x640 1 push up, 12.8ms
# Speed: 1.7ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_116.jpg: 384x640 1 push up, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_117.jpg: 384x640 1 push up, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_118.jpg: 384x640 1 push up, 10.1ms
# Speed: 1.6ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_119.jpg: 384x640 1 push up, 9.6ms
# Speed: 1.7ms preprocess, 9.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame
 9.7ms
# Speed: 2.3ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_58.jpg: 384x640 1 push up, 10.8ms
# Speed: 2.0ms preprocess, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_59.jpg: 384x640 1 push up, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_6.jpg: 384x640 1 push up, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_60.jpg: 384x640 1 push up, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_61.jpg: 384x640 1 push up, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_62.jpg: 384x640 1 push up, 11.6ms
# Speed: 1.8ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_63.jpg: 384x640 1 push up, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_64.jpg: 384x640 1 push up, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_65.jpg: 384x640 1 push up, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_66.jpg: 384x640 1 push up, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_67.jpg: 384x640 1 hip thrust, 1 push up, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_68.jpg: 384x640 1 hip thrust, 1 push up, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_69.jpg: 384x640 1 hip thrust, 1 push up, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_7.jpg: 384x640 1 push up, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_70.jpg: 384x640 1 push up, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_71.jpg: 384x640 1 hip thrust, 1 push up, 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_72.jpg: 384x640 1 push up, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_73.jpg: 384x640 1 push up, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_74.jpg: 384x640 1 push up, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_75.jpg: 384x640 1 push up, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_76.jpg: 384x640 1 push up, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_77.jpg: 384x640 1 push up, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_78.jpg: 384x640 1 push up, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_79.jpg: 384x640 1 push up, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_8.jpg: 384x640 1 push up, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_80.jpg: 384x640 1 push up, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_81.jpg: 384x640 2 push ups, 8.9ms
# Speed: 1.8ms preprocess, 8.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_82.jpg: 384x640 1 push up, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_83.jpg: 384x640 1 push up, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_84.jpg: 384x640 1 push up, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_85.jpg: 384x640 1 push up, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_86.jpg: 384x640 1 push up, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_87.jpg: 384x640 1 push up, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_88.jpg: 384x640 1 push up, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_89.jpg: 384x640 1 push up, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_9.jpg: 384x640 1 push up, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_90.jpg: 384x640 1 push up, 11.2ms
# Speed: 2.2ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_91.jpg: 384x640 1 push up, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_92.jpg: 384x640 1 push up, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_93.jpg: 384x640 1 push up, 10.2ms
# Speed: 1.8ms preprocess, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_94.jpg: 384x640 1 push up, 9.3ms
# Speed: 1.8ms preprocess, 9.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_95.jpg: 384x640 1 push up, 10.4ms
# Speed: 1.8ms preprocess, 10.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_96.jpg: 384x640 1 push up, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_97.jpg: 384x640 1 hip thrust, 1 push up, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_98.jpg: 384x640 1 push up, 10.0ms
# Speed: 2.4ms preprocess, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_99.jpg: 384x640 1 push up, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Get predicted Class based on max confidence

# %%
if max_confidence:
    best_class = max(max_confidence, key=max_confidence.get)
    best_score = max_confidence[best_class]
    print(f"Predicted Class: {best_class} with max confidence: {best_score:.2f}")
else:
    best_class, best_score = None, None
    print("No predictions found.")
# Out:
# Predicted Class: push up with max confidence: 0.91

# %% [markdown]
# ### Analysis:
# - The two videos tested here are videos that have never been seen by model
# - The pipeline I structured here classified both videos accurately as a push-up
# - Using max confidence to classify exercises improves the prediction accuracy

# %% [markdown]
# ### Skip or Trigger Pose Estimation

# %%
if best_class.lower() == "push up":
    flag_pushup = True
    print("Push-up detected — Running pose estimation...")
else:
    print("Not a push-up or low confidence — skipping pose estimation.")
# Out:
# Push-up detected — Running pose estimation...

# %% [markdown]
# ### Determine Most Visible Arm

# %%
if flag_pushup:
    
    left_visible_count = 0
    right_visible_count = 0

    for img_name in sorted(os.listdir(frame_folder)):
        img_path = os.path.join(frame_folder, img_name)
        results = pose_model(img_path)

        for r in results:
            if r.keypoints is None:
                continue
            conf = r.keypoints.conf[0]
            left_visible = all(conf[i] > 0.5 for i in [5, 7, 9])
            right_visible = all(conf[i] > 0.5 for i in [6, 8, 10])
            if left_visible: left_visible_count += 1
            if right_visible: right_visible_count += 1

    if right_visible_count >= left_visible_count:
        side = "right"
    else:
        side = "left"
        
    print(f"Using {side} arm for angle tracking.")
# Out:
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame
angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    ba = a - b
    bc = c - b
    cosine = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine, -1.0, 1.0))
    return np.degrees(angle)

# %% [markdown]
# ### Track the change in angle for each push up frame

# %%
# Choose which arm to track (use code from earlier to auto-select if needed)
if side == "right":
    k_idx = [6, 8, 10]
else:
    k_idx = [5, 7, 9]


angle_tracking = []

# Process each frame
if overlay_flag:
    for img_name in sorted(os.listdir(frame_folder)):
        img_path = os.path.join(frame_folder, img_name)
        frame = cv2.imread(img_path)
        results = pose_model(img_path)

        for r in results:
            if r.keypoints is None:
                continue

            conf = r.keypoints.conf[0]
            xy = r.keypoints.xy[0]

            if all(conf[i] > 0.5 for i in k_idx):
                a = xy[k_idx[0]].cpu().numpy()
                b = xy[k_idx[1]].cpu().numpy()
                c = xy[k_idx[2]].cpu().numpy()
                angle = calculate_angle(a, b, c)
                angle_tracking.append(angle)
                # Draw keypoints
                for point in [a, b, c]:
                    cv2.circle(frame, tuple(map(int, point)), 6, (0, 255, 0), -1)

                # Draw lines connecting keypoints
                cv2.line(frame, tuple(map(int, a)), tuple(map(int, b)), (255, 0, 0), 2)
                cv2.line(frame, tuple(map(int, b)), tuple(map(int, c)), (255, 0, 0), 2)

                # Annotate angle
                angle_text = f"{int(angle)} deg"
                pos = tuple(map(int, b))
                cv2.putText(frame, angle_text, (pos[0] + 10, pos[1] - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

        # Save annotated frame
        out_path = os.path.join(output_folder, img_name)
        cv2.imwrite(out_path, frame)

    print(f"Annotated frames with angles saved to: {output_folder}")
else:
    print("No overlay needed. Skipping angle annotation. ")
# Out:
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_0.jpg: 384x640 1 person, 169.2ms
# Speed: 14.7ms preprocess, 169.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_1.jpg: 384x640 1 person, 75.6ms
# Speed: 3.3ms preprocess, 75.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_10.jpg: 384x640 1 person, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_100.jpg: 384x640 1 person, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_101.jpg: 384x640 1 person, 12.3ms
# Speed: 1.6ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_102.jpg: 384x640 1 person, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_103.jpg: 384x640 1 person, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_104.jpg: 384x640 1 person, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_105.jpg: 384x640 1 person, 12.4ms
# Speed: 1.6ms preprocess, 12.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_106.jpg: 384x640 1 person, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_107.jpg: 384x640 1 person, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_108.jpg: 384x640 1 person, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_109.jpg: 384x640 1 person, 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_11.jpg: 384x640 1 person, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_110.jpg: 384x640 1 person, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_111.jpg: 384x640 1 person, 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_112.jpg: 384x640 1 person, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_113.jpg: 384x640 1 person, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_114.jpg: 384x640 1 person, 10.2ms
# Speed: 1.6ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_115.jpg: 384x640 1 person, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_116.jpg: 384x640 1 person, 13.3ms
# Speed: 1.6ms preprocess, 13.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_117.jpg: 384x640 1 person, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_118.jpg: 384x640 1 person, 15.1ms
# Speed: 1.7ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_119.jpg: 384x640 1 person, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_12.jpg: 384x640 1 person, 11.6ms
# Speed: 1.6ms preprocess, 11.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_120.jpg: 384x640 1 person, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_121.jpg: 384x640 1 person, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_122.jpg: 384x640 1 person, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_123.jpg: 384x640 1 person, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame_124.jpg: 384x640 2 persons, 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 f:\LSU_Fullstack_AI_Machine_Learning_Course\capstone_project\video_frames\frame